# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm

import numpy as np

import sklearn
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix

import matplotlib.pyplot as plt
import seaborn as sn

pd.set_option('display.max_rows', 300) # specifies number of rows to show
pd.options.display.float_format = '{:40,.4f}'.format # specifies default number format to 4 decimal places
plt.style.use('ggplot') # specifies that graphs should use ggplot styling
# %matplotlib inline

# %%
cases_18 = pd.read_csv('ass1_dataset_1.csv')

# %%
cases_18.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 152 entries, 0 to 151
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   local_authority_area       152 non-null    object
#  1   18ratio                    152 non-null    float64
#  2   clean_air                  152 non-null    float64
#  3   clean_environ              152 non-null    float64
#  4   health_training            152 non-null    float64
#  5   school_awareness           152 non-null    float64
#  6   media_awareness            152 non-null    float64
#  7   sub_counselling            152 non-null    float64
#  8   average_funding_perperson  152 non-null    float64
#  9   region                     152 non-null    object
#  10  local_authority_type       152 non-null    object
#  11  18pop_ratio_f/m            152 non-null    float64
#  12  18case_ratio_f/m           152 non-null    float64
# ...

# %%
cases_18.head(7)
# Out:
#            local_authority_area                                  18ratio  \
# 0          Barking and Dagenham                                   0.4197
# 1                        Barnet                                   0.2172
# 2                      Barnsley                                   0.2044
# 3  Bath and North East Somerset                                   0.2609
# 4                       Bedford                                   0.2153
# 5                        Bexley                                   0.2875
# 6                    Birmingham                                   0.3614
#
#                                  clean_air  \
# 0                                  15.1079
# 1                                  22.7273
# 2                                  25.6250
# 3                                  20.4969
# 4                                  28.4615
# 5                                  36.1809
# 6                                   7.7016
#
# ...

# %%
#encoding of categorical data

# %%
cases_18_numeric = pd.get_dummies(cases_18.drop('local_authority_area',axis=1))

# %%
cases_18_numeric.info()
cases_18_numeric.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 152 entries, 0 to 151
# Data columns (total 24 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   18ratio                                       152 non-null    float64
#  1   clean_air                                     152 non-null    float64
#  2   clean_environ                                 152 non-null    float64
#  3   health_training                               152 non-null    float64
#  4   school_awareness                              152 non-null    float64
#  5   media_awareness                               152 non-null    float64
#  6   sub_counselling                               152 non-null    float64
#  7   average_funding_perperson                     152 non-null    float64
#  8   18pop_ratio_f/m                               152 non-null    float64
# ...

# %%
cases_18_final = cases_18_numeric.drop(['region_South West','local_authority_type_non_metropolitan_county'],axis=1)

# %%
cases_18_final.head(10)
# Out:
#                                    18ratio  \
# 0                                   0.4197
# 1                                   0.2172
# 2                                   0.2044
# 3                                   0.2609
# 4                                   0.2153
# 5                                   0.2875
# 6                                   0.3614
# 7                                   0.6764
# 8                                   0.4222
# 9                                   0.2405
#
#                                  clean_air  \
# 0                                  15.1079
# 1                                  22.7273
# 2                                  25.6250
# 3                                  20.4969
# 4                                  28.4615
# 5                                  36.1809
# 6                                   7.7016
# 7                                  16.4835
# 8                                  24.2424
# 9                                  27.3632
#
# ...

# %%
#cases_18_final = cases_18.drop('local_authority_area',axis=1)
cases_18_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 152 entries, 0 to 151
# Data columns (total 22 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   18ratio                                    152 non-null    float64
#  1   clean_air                                  152 non-null    float64
#  2   clean_environ                              152 non-null    float64
#  3   health_training                            152 non-null    float64
#  4   school_awareness                           152 non-null    float64
#  5   media_awareness                            152 non-null    float64
#  6   sub_counselling                            152 non-null    float64
#  7   average_funding_perperson                  152 non-null    float64
#  8   18pop_ratio_f/m                            152 non-null    float64
#  9   18case_ratio_f/m                           152 non-null    float64
# ...

# %%
#check correlation between variables
df = cases_18_final
plt.rcParams["axes.grid"] = False
f = plt.figure(figsize=(11, 8))
plt.matshow(df.corr(), fignum=f.number)
plt.xticks(range(df.shape[1]), df.columns, fontsize=8, rotation=60)
plt.yticks(range(df.shape[1]), df.columns, fontsize=7)
cb = plt.colorbar()
cb.ax.tick_params(labelsize=14)
plt.title('Correlation Matrix', fontsize=15)
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')

# %%
#VIF
from statsmodels.stats.outliers_influence import variance_inflation_factor 
from statsmodels.tools.tools import add_constant

def drop_column_using_vif_(df, thresh=5):
    '''
    Calculates VIF each feature in a pandas dataframe, and repeatedly drop the columns with the highest VIF
    A constant must be added to variance_inflation_factor or the results will be incorrect

    :param df: the pandas dataframe containing only the predictor features, not the response variable
    :param thresh: (default 5) the threshould VIF value. If the VIF of a variable is greater than thresh, it should be removed from the dataframe
    :return: dataframe with multicollinear features removed
    '''
    while True:
        # adding a constatnt item to the data. add_constant is a function from statsmodels (see the import above)
        df_with_const = add_constant(df)

        vif_df = pd.Series([variance_inflation_factor(df_with_const.values, i) 
               for i in range(df_with_const.shape[1])], name= "VIF",
              index=df_with_const.columns).to_frame()

        # drop the const
        vif_df = vif_df.drop('const')
        
        # if the largest VIF is above the thresh, remove a variable with the largest VIF
        # If there are multiple variabels with VIF>thresh, only one of them is removed. This is because we want to keep as many variables as possible
        if vif_df.VIF.max() > thresh:
            # If there are multiple variables with the maximum VIF, choose the first one
            index_to_drop = vif_df.index[vif_df.VIF == vif_df.VIF.max()].tolist()[0]
            print('Dropping: {}'.format(index_to_drop))
            df = df.drop(columns = index_to_drop)
        else:
            # No VIF is above threshold. Exit the loop
            break

    return df

# %%
cases_18_final.columns
# Out:
# Index(['18ratio', 'clean_air', 'clean_environ', 'health_training',
#        'school_awareness', 'media_awareness', 'sub_counselling',
#        'average_funding_perperson', '18pop_ratio_f/m', '18case_ratio_f/m',
#        'region_East Midlands', 'region_East of England', 'region_London',
#        'region_North East', 'region_North West', 'region_South East',
#        'region_West Midlands', 'region_Yorkshire and the Humber',
#        'local_authority_type_london_borough',
#        'local_authority_type_metropolitan_borough',
#        'local_authority_type_other_london',
#        'local_authority_type_unitary_authority'],
#       dtype='object')

# %%
cases_18_vif = drop_column_using_vif_(cases_18_final.drop('18ratio', axis=1))
print('The columns remaining after VIF selection are:')
print(cases_18_vif.columns)
# Out:
# Dropping: clean_environ
# Dropping: region_London
# Dropping: local_authority_type_other_london
# Dropping: local_authority_type_london_borough
# The columns remaining after VIF selection are:
# Index(['clean_air', 'health_training', 'school_awareness', 'media_awareness',
#        'sub_counselling', 'average_funding_perperson', '18pop_ratio_f/m',
#        '18case_ratio_f/m', 'region_East Midlands', 'region_East of England',
#        'region_North East', 'region_North West', 'region_South East',
#        'region_West Midlands', 'region_Yorkshire and the Humber',
#        'local_authority_type_metropolitan_borough',
#        'local_authority_type_unitary_authority'],
#       dtype='object')
# /Users/luomengjiao/opt/anaconda3/lib/python3.8/site-packages/statsmodels/stats/outliers_influence.py:193: RuntimeWarning: divide by zero encountered in double_scalars
#   vif = 1. / (1. - r_squared_i)
# ...

# %%
cases_18_relationship = sm.OLS(endog=cases_18_final[['18ratio']], exog=sm.add_constant(cases_18_vif)).fit()
cases_18_relationship.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                18ratio   R-squared:                       0.316
# Model:                            OLS   Adj. R-squared:                  0.230
# Method:                 Least Squares   F-statistic:                     3.648
# Date:                Sat, 13 Nov 2021   Prob (F-statistic):           1.11e-05
# Time:                        21:17:23   Log-Likelihood:                 113.98
# No. Observations:                 152   AIC:                            -192.0
# Df Residuals:                     134   BIC:                            -137.5
# Df Model:                          17
# Covariance Type:            nonrobust
# ...
#                                                 coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------
# ...

# %%
# plot 
plt.scatter(cases_18_relationship.fittedvalues, cases_18_relationship.resid)
# adding title and labels
plt.xlabel('Fitted cases_percentage')
plt.ylabel('Residual')
plt.title('Residual vs. Fitted Plot of cases_percentage')
plt.show()
